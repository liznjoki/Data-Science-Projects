# %% [markdown]
# <a href="https://colab.research.google.com/github/liznjoki/Data-Science-Projects/blob/main/GroupingQuestions_SimilarityScore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize, TreebankWordDetokenizer
from nltk.corpus import stopwords
from nltk import PorterStemmer
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors

import nltk
import string

import spacy

nltk.download("stopwords")
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

nlp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
df= pd.read_csv("/content/Customer Representative.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                     Job Position  \
# 0           1  Customer Service Representative
# 1           2  Customer Service Representative
# 2           3  Customer Service Representative
# 3           4  Customer Service Representative
# 4           5  Customer Service Representative
#
#                                             Question  \
# 0                What are Your Biggest Achievements?
# 1  Name any Two Improvements You Made in the Prev...
# 2  Tell me about a professional accomplishment yo...
# 3  Have you ever utilized customer feedback to en...
# 4  Have You Used Customer Feedback to Ensure Busi...
#
#                                               Answer Answer Rating  \
# 0  During my last job, I learned some interperson...       Average
# 1  As a few of my team members were late to work,...          Good
# 2  One of my proudest professional accomplishment...          Good
# 3  Yes, I've leveraged customer feedback to impro...       Average
# 4  Yes, I have used customer feedback to improve ...          Good
#
#   Interview Phases      Skill Assessed
# 0          General     Accomplishments
# 1          General     Accomplishments
# 2          General     Accomplishments
# 3    Role Specific  Analytical mindset
# 4    Role Specific  Analytical mindset

# %%
df= df.drop(columns=["Skill Assessed"], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1262 entries, 0 to 1261
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   S.No.      1262 non-null   int64
#  1   Job Role   1262 non-null   object
#  2   Questions  1262 non-null   object
#  3   Category   1262 non-null   object
#  4   Answers    1262 non-null   object
#  5   Ratings    1262 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 59.3+ KB

# %%
df.shape
# Out:
# (1262, 6)

# %%
df.isna().sum()
# Out:
# S.No.        0
# Job Role     0
# Questions    0
# Category     0
# Answers      0
# Ratings      0
# dtype: int64

# %%
df.shape
# Out:
# (459, 6)

# %% [markdown]
# #Text cleaning and processing

# %%
#preprocessing of the dataset, removing punctuations and making lowercase

def preprocess_text_column(df, column_name):
  #stemmer= PorterStemmer()
  #stop_words = set(stopwords.words("english"))
  #Preprocess a single text
  def preprocess_text(text):
    #Remove punctuation and convert to lowercase
    text= text.translate(str.maketrans("", "", string.punctuation)).lower()

    #Tokenize the text
    words= word_tokenize(text)

    #Remove stop words and apply stemming
    #words= [stemmer.stem(word) for word in words if word not in stop_words]

    #Join the processed words back into a single string

    return " ".join(words)

  df[column_name] = df[column_name].apply(preprocess_text)

  return df

# %%
cleaned_df = preprocess_text_column(df, "Question")

# %%
cleaned_df.head()
# Out:
#    Unnamed: 0                     Job Position  \
# 0           1  Customer Service Representative
# 1           2  Customer Service Representative
# 2           3  Customer Service Representative
# 3           4  Customer Service Representative
# 4           5  Customer Service Representative
#
#                                             Question  \
# 0                 what are your biggest achievements
# 1  name any two improvements you made in the prev...
# 2  tell me about a professional accomplishment yo...
# 3  have you ever utilized customer feedback to en...
# 4  have you used customer feedback to ensure busi...
#
#                                               Answer Answer Rating  \
# 0  During my last job, I learned some interperson...       Average
# 1  As a few of my team members were late to work,...          Good
# 2  One of my proudest professional accomplishment...          Good
# 3  Yes, I've leveraged customer feedback to impro...       Average
# 4  Yes, I have used customer feedback to improve ...          Good
#
#   Interview Phases      Skill Assessed
# 0          General     Accomplishments
# 1          General     Accomplishments
# 2          General     Accomplishments
# 3    Role Specific  Analytical mindset
# 4    Role Specific  Analytical mindset

# %%
cleaned_df.Question.unique()

# %%
cleaned_df.reset_index(inplace=True, drop=True)

# %% [markdown]
# #Grouping Question according to similarity scores using 0.6 similarity score threshold.

# %%
#Extract TF-IDF features from the Question
tfidf_vectorizer= TfidfVectorizer()
tfidf_matrix= tfidf_vectorizer.fit_transform(cleaned_df["Question"])

#Calculate the pairwise cosine similarity between Question
cosine_similarities= cosine_similarity(tfidf_matrix)

#Define a threshold for grouping Question

threshold= 0.6

#Create an empty list to store the groups

grouped_Question= []

#Create a dictionary to store question-to-group mapping

question_to_group = {}

#Counter for group numbering

group_number= 1

#Iterate through the cosine similarity matrix
for i in range(len(cleaned_df)):

  #Check if the question is already assigned to a group
  if i not in question_to_group:

    #Initialize an empty list to store the current group
    current_group= [i]

    #Iterate through the cosine similarity scores for the current question
    for j in range(len(cleaned_df)):
      if i!=j and cosine_similarities[i, j] >= threshold:
        current_group.append(j)

        #Mark the question assigned to the current group
        question_to_group[j] = group_number

    #If the current group containts more than one question, add it to the list of groups
    if len(current_group) > 1:
      grouped_Question.append(current_group)

      #Increment the group number
      group_number +=1

# %%
 #Print the grouped Question with group numbers
for group_number, group in enumerate(grouped_Question, start=1):
  print(f"Group {group_number}")
  for i in group:
    print(cleaned_df.loc[i, "Question"])
# Out:
# Group 1
# what are your career goals
# what are your career goals
# what are your longterm career goals
# Group 2
# where do you see yourself in three years
# where do you see yourself in five years
# Group 3
# where do you see yourself five years down the line
# where do you see yourself in five years
# Group 4
# what are you hoping to do in five years
# what are you hoping to do in five years
# Group 5
# how do you respond when you do not know the answer to a question
# how do you respond to a customers question for which you do not know the answer
# how do you handle a situation where you do not know the answer to a customers question
# has a customer ever asked a question you did not know the answer to how did you respond
# what do you do when you don ’ t know the answer to a customer ’ s question
# Group 6
# what do you know about our products or services
# what do you think of our companys products and services
# Group 7
# what do you know about this company
# what do you know about our company or product
# Group 8
# why do you want to work here
# why do you want to work here
# why do you want to work in customer service
# why do you want to work in customer service
# why do you want to work in customer service
# Group 9
# what do you think of our product or service
# what do you know about our product service or company
# Group 10
# why do you want to work in customer service at this organisation
# why do you want to work in customer service
# why do you want to work for this company
# why do you want to work in customer service
# why do you want to work in customer service
# Group 11
# what do you think of this companys products or services
# what do you think of our companys products and services
# Group 12
# how well do you know our company and product
# what do you know about our company or product
# what do you know about our product service or company
# Group 13
# describe a time when you provided highquality customer service
# describe a time when you provided or observed highquality customer service
# Group 14
# how would you improve the experience of dissatisfied customers
# how would you improve a dissatisfied customers experience
# how would you improve the experience of dissatisfied customers
# how can you improve a dissatisfied customers experience
# Group 15
# tell us about a time you went the extra mile for a customer
# tell us about a time you went the extra mile for a customer
# Group 16
# how do you measure a successful customer service experience
# how do you measure a successful customer service experience
# Group 17
# tell me about a time when you went above and beyond for a customer
# tell me about a time you went above and beyond what was expected to please a customer
# describe a time when you went above and beyond for a customer
# Group 18
# give an example where you did not meet the customer ’ s expectations
# give me an example where you did not meet a clients expectations what happened and how did you attempt to fix the situation
# Group 19
# tell me about the best customer service youve ever had
# tell me about the worst customer experience youve ever had
# Group 20
# define good customer service
# how would you define good customer service
# how do you define customer service
# Group 21
# what does good customer service mean to you
# what does customer service mean to you
# what does customer service mean to you
# what does customer service mean to you
# what does excellent customer service mean to you
# Group 22
# what skills are essential for a great customer service representative to have
# what skills should a great customer service representative have
# what skills should a great customer service representative have
# Group 23
# what is customer service
# what is customer service
# what is customer service
# Group 24
# what skills does a great customer service representative need
# what skills should a great customer service representative have
# what skills should a great customer service representative have
# what skills does a great customer service representative need
# Group 25
# are you proficient in the use of any customer service software
# how proficient are you in customer service software
# Group 26
# what do you consider to be excellent customer service
# what do you consider to be the biggest challenge in providing excellent customer service
# what do you consider to be your greatest customer service strength
# Group 27
# what steps do you take to ensure that you are providing accurate information to customers
# how do you ensure that your customer service team is providing accurate and consistent information to customers
# Group 28
# what experience do you have working in customer service
# what experience do you have in customer service
# Group 29
# what experience do you have with using customer service software
# what customer service tools do you have experience using
# what customer service software do you have experience using
# what customer service tools do you have experience using
# what experience do you have with crm software
# Group 30
# what is your experience with crm software
# what experience do you have with crm software
# Group 31
# how would you handle a situation where your customer is wrong
# how would you handle a customer you know is wrong
# how do you handle a customer you know is wrong
# how would you handle a customer you know is wrong
# how would you handle a situation where your customer is wrong
# how would you handle a customer you know is wrong
# how would you handle a situation where your customer is wrong
# Group 32
# what is the best way to deal with an angry or abusive customer
# what is the best way to deal with an angry or abusive customer
# Group 33
# what steps do you take to deescalate a customer argument
# what steps do you take to deescalate a customer argument
# Group 34
# how do you deal with the question you don ’ t know the answer that customer asked
# what do you do when you don ’ t know the answer to a customer ’ s question
# Group 35
# give an example of a time you faced a difficult customer and how you resolved the situation
# give an example of a time you faced a difficult customer and how you resolved the situation
# Group 36
# describe a time when you had to handle an angry or difficult customer
# how do you handle an angry customer
# Group 37
# tell me about yourself
# tell me something interesting about yourself
# tell me about yourself
# Group 38
# what do you like about working in customer service and what do you not like
# what do you like most about working in customer service
# what do you like most about customer service
# do you like working in teams
# Group 39
# why do you want to work as a customer service representative
# why do you want to work in customer service
# why do you want to work in customer service
# why do you want to work in customer service
# Group 40
# why should we hire you
# why should we hire you
# Group 41
# how do you ensure that your customer service team is providing a consistent customer experience
# how do you ensure that your customer service team is providing a seamless omnichannel experience for customers
# how do you ensure that your customer service team is providing accurate and consistent information to customers
# Group 42
# what are your strengths whats your greatest weakness
# what is your greatest weakness
# Group 43
# what motivates you in your career
# what motivates you in your career
# Group 44
# describe a mistake that you made handling a customer service issue and how you mitigated it
# describe a mistake you made handling a customer service problem and how you would handle it now
# Group 45
# have you ever made a mistake while handling a customer service problem how would you manage it now
# have you ever made a mistake while handling a customer service problem how would you manage it now
# tell us about a mistake you did while handling a customer service problem how did you manage it
# describe a mistake you made handling a customer service problem and how you would handle it now
# Group 46
# how do you balance local volume with internal responsibilities like followups or administrative work
# how do you balance local volume with internal responsibilities like followups or administrative work
# Group 47
# how would past colleagues or classmates describe you
# how would past coworkers or classmates describe you
# Group 48
# what is your greatest strength
# what do you consider to be your greatest customer service strength
# Group 49
# have you ever made a mistake at work and how did you handle it
# describe a time when you made a mistake at work and how you handled it
# Group 50
# how do you keep yourself motivated when people are being mean to you
# how do you keep yourself motivated when people are being mean to you
# Group 51
# how would you manage a customer whose issue is taking too long to resolve
# how would you manage a customer whose issue is taking too long to resolve
# how would you manage a customer whose issue is taking too long to resolve
# Group 52
# what would you do if you did not know how to help a customer
# what would you do if you did not know how to help a customer
# Group 53
# how do you handle a customer who complains about a known issue with a product or service
# how you would handle a customer who was upset about a known problem with your product or service
# how you would handle a customer who was upset about a known problem with your product or service
# Group 54
# discuss how youd handle a customer upset about a known problem with your product service
# how you would handle a customer who was upset about a known problem with your product or service
# how you would handle a customer who was upset about a known problem with your product or service
# Group 55
# what steps will it take if you do not know how to solve a customers problem
# what steps will it take if you dont know how to solve a customers problem
# Group 56
# explain how to tackle the customer language barrier that exists in between
# explain how to tackle the customer language barrier that exists in between
# explain how to tackle the customer language barrier that exists in between
# Group 57
# what would you do if a frustrated customer complained about a wellknown flaw with a company product
# what would you do if a frustrated customer complained about a widely known problem with the company ’ s product
# Group 58
# what would you do if you couldnt understand what the customer was asking
# what would you do if you couldn ’ t understand what the customer was asking
# Group 59
# what do you do when you don ’ t know how to help a customer
# what do you do when you don ’ t know the answer to a customer ’ s question
# Group 60
# has a customer ever asked a question you didnt know the answer to how did you respond
# has a customer ever asked a question you did not know the answer to how did you respond
# Group 61
# describe a time you collaborated with a peer to solve a problem
# describe a time you collaborated with a peer to solve a problem
# describe a time you collaborated with a peer to solve a problem
# Group 62
# how do you collaborate with your team members to solve a customers problem
# how do you collaborate with your team members to solve a customers problem
# Group 63
# have you ever successfully managed a conflict between two colleagues
# have you ever successfully managed a conflict between two colleagues
# Group 64
# tell us about a time you that you worked successfully within a team
# tell us about a time that you worked successfully within a team

# %%
#Create a new 'labels' column to hold group numbers
cleaned_df["labels"] = None


#Assign group number to the 'labels' column
for i, group in enumerate(grouped_Question, start=1):
  cleaned_df.loc[group, "labels"]= i

#Show the modified DataFrame
cleaned_df
# Out:
#      Unnamed: 0                     Job Position  \
# 0             1  Customer Service Representative
# 1             2  Customer Service Representative
# 2             3  Customer Service Representative
# 3             4  Customer Service Representative
# 4             5  Customer Service Representative
# ..          ...                              ...
# 454         456  Customer Service Representative
# 455         457  Customer Service Representative
# 456         458  Customer Service Representative
# 457         459  Customer Service Representative
# 458         460  Customer Service Representative
#
#                                               Question  \
# 0                   what are your biggest achievements
# 1    name any two improvements you made in the prev...
# 2    tell me about a professional accomplishment yo...
# 3    have you ever utilized customer feedback to en...
# 4    have you used customer feedback to ensure busi...
# ..                                                 ...
# 454  have you ever collaborated with other customer...
# 455  how do you motivate your team to provide excel...
# 456  how do you collaborate with your team members ...
# 457  have you ever successfully managed a conflict ...
# 458  tell us about a time that you worked successfu...
#
#                                                 Answer Answer Rating  \
# 0    During my last job, I learned some interperson...       Average
# 1    As a few of my team members were late to work,...          Good
# 2    One of my proudest professional accomplishment...          Good
# 3    Yes, I've leveraged customer feedback to impro...       Average
# 4    Yes, I have used customer feedback to improve ...          Good
# ..                                                 ...           ...
# 454  Yes, I often work with others if I can’t solve...          Good
# 455  I believe that providing excellent customer se...          Good
# 456   I recently worked for a tech company that pro...       Average
# 457  While working for my current employer, I asked...          Good
# 458  In my previous role there were multiple depart...          Good
#
#     Interview Phases               Skill Assessed labels
# 0            General              Accomplishments   None
# 1            General              Accomplishments   None
# 2            General              Accomplishments   None
# 3      Role Specific           Analytical mindset   None
# 4      Role Specific           Analytical mindset   None
# ..               ...                          ...    ...
# 454       Behavioral  Team Work and Collaboration   None
# 455       Behavioral  Team Work and Collaboration   None
# 456       Behavioral  Team Work and Collaboration     62
# 457       Behavioral  Team Work and Collaboration     63
# 458       Behavioral  Team Work and Collaboration     64
#
# [459 rows x 8 columns]

# %%
cleaned_df.labels.nunique()
# Out:
# 64

# %%
#sort the dataframe according to the group numbers
cleaned_df.sort_values(by="labels", inplace=True)
cleaned_df
# Out:
#      Unnamed: 0                     Job Position  \
# 11           12  Customer Service Representative
# 18           19  Customer Service Representative
# 19           20  Customer Service Representative
# 12           13  customer service representative
# 14           15  customer service representative
# ..          ...                              ...
# 450         452         Customer Service Manager
# 451         453         Customer Service Manager
# 452         454         Customer Service Manager
# 454         456  Customer Service Representative
# 455         457  Customer Service Representative
#
#                                               Question  \
# 11                          what are your career goals
# 18                          what are your career goals
# 19                 what are your longterm career goals
# 12            where do you see yourself in three years
# 14   where do you see yourself five years down the ...
# ..                                                 ...
# 450  describe a situation where you had to delegate...
# 451  share an example of a time when you had to pro...
# 452                 do you work well with other people
# 454  have you ever collaborated with other customer...
# 455  how do you motivate your team to provide excel...
#
#                                                 Answer Answer Rating  \
# 11   my goals include mastering the role of custome...          Good
# 18   I am passionate about customer service and see...          Good
# 19   My long-term career goals include continuing t...          Good
# 12   within three to five years i hope to have move...          Good
# 14   i would like to take on additional roles and r...       Average
# ..                                                 ...           ...
# 450  As a project leader for a digital marketing te...          Good
# 451  I once led a team on which one individual cons...          Good
# 452  Open Communication: I prioritize open and tran...          Good
# 454  Yes, I often work with others if I can’t solve...          Good
# 455  I believe that providing excellent customer se...          Good
#
#     Interview Phases               Skill Assessed labels
# 11           General                 Career Goals      1
# 18           General                 Career Goals      1
# 19           General                 Career Goals      1
# 12           General                 Career Goals      2
# 14           General                 Career Goals      3
# ..               ...                          ...    ...
# 450       Behavioral  Team Work and Collaboration   None
# 451       Behavioral  Team Work and Collaboration   None
# 452       Behavioral  Team Work and Collaboration   None
# 454       Behavioral  Team Work and Collaboration   None
# 455       Behavioral  Team Work and Collaboration   None
#
# [459 rows x 8 columns]

# %%
cleaned_df["labels"].isnull().sum()
# Out:
# 198

# %% [markdown]
# #Experimenting with three different similarity thresholds

# %%
#Extract TF-IDF features from the Question
tfidf_vectorizer= TfidfVectorizer()
tfidf_matrix= tfidf_vectorizer.fit_transform(cleaned_df["Question"])

#Calculate the pairwise cosine similarity between Question
cosine_similarities= cosine_similarity(tfidf_matrix)

# Experiment with different threshold values
threshold_values = [0.5, 0.6, 0.7, 0.8]

for threshold in threshold_values:
    grouped_Question = []
    question_to_group = {}
    group_number = 1

    for i in range(len(cleaned_df)):
        if i not in question_to_group:
            current_group = [i]
            for j in range(len(cleaned_df)):
                if i != j and cosine_similarities[i, j] >= threshold:
                    current_group.append(j)
                    question_to_group[j] = group_number

            if len(current_group) > 1:
                grouped_Question.append(current_group)
                group_number += 1

    # Print the grouped Question with group numbers for the current threshold
    print(f"Threshold: {threshold}")
    for group_number, group in enumerate(grouped_Question, start=1):
        print(f"Group {group_number}")
        for i in group:
            print(cleaned_df.loc[i, "Question"])
    print("\n")

# %% [markdown]
# ##Replace all questions in the same group with the first question asked.

# %%
# Dictionary to store the first question in each group
first_questions = {}

# Iterate through each row in the DataFrame
for index, row in cleaned_df.iterrows():
    label = row['labels']
    question = row['Question']

    # If the label is encountered for the first time and it's not a NaN value, store the question as the first question for that label
    if pd.notnull(label) and label not in first_questions:
        first_questions[label] = question

# Function to replace questions with first questions based on the label, else keep the original question
def replace_with_first_question(row):
    label = row['labels']
    question = row['Question']
    if pd.notnull(label):
        return first_questions.get(label, question)
    else:
        return question

# Create a new column 'generalized interview questions' by mapping Labels to first questions
cleaned_df['generalized interview questions'] = cleaned_df.apply(replace_with_first_question, axis=1)

# %%
cleaned_df
# Out:
#      Unnamed: 0                     Job Position  \
# 11           12  Customer Service Representative
# 18           19  Customer Service Representative
# 19           20  Customer Service Representative
# 12           13  customer service representative
# 14           15  customer service representative
# ..          ...                              ...
# 450         452         Customer Service Manager
# 451         453         Customer Service Manager
# 452         454         Customer Service Manager
# 454         456  Customer Service Representative
# 455         457  Customer Service Representative
#
#                                               Question  \
# 11                          what are your career goals
# 18                          what are your career goals
# 19                 what are your longterm career goals
# 12            where do you see yourself in three years
# 14   where do you see yourself five years down the ...
# ..                                                 ...
# 450  describe a situation where you had to delegate...
# 451  share an example of a time when you had to pro...
# 452                 do you work well with other people
# 454  have you ever collaborated with other customer...
# 455  how do you motivate your team to provide excel...
#
#                                                 Answer Answer Rating  \
# 11   my goals include mastering the role of custome...          Good
# 18   I am passionate about customer service and see...          Good
# 19   My long-term career goals include continuing t...          Good
# 12   within three to five years i hope to have move...          Good
# 14   i would like to take on additional roles and r...       Average
# ..                                                 ...           ...
# 450  As a project leader for a digital marketing te...          Good
# 451  I once led a team on which one individual cons...          Good
# 452  Open Communication: I prioritize open and tran...          Good
# 454  Yes, I often work with others if I can’t solve...          Good
# 455  I believe that providing excellent customer se...          Good
#
#     Interview Phases               Skill Assessed labels  \
# 11           General                 Career Goals      1
# 18           General                 Career Goals      1
# 19           General                 Career Goals      1
# 12           General                 Career Goals      2
# 14           General                 Career Goals      3
# ..               ...                          ...    ...
# 450       Behavioral  Team Work and Collaboration   None
# 451       Behavioral  Team Work and Collaboration   None
# 452       Behavioral  Team Work and Collaboration   None
# 454       Behavioral  Team Work and Collaboration   None
# 455       Behavioral  Team Work and Collaboration   None
#
#                        generalized interview questions
# 11                          what are your career goals
# 18                          what are your career goals
# 19                          what are your career goals
# 12            where do you see yourself in three years
# 14   where do you see yourself five years down the ...
# ..                                                 ...
# 450  describe a situation where you had to delegate...
# 451  share an example of a time when you had to pro...
# 452                 do you work well with other people
# 454  have you ever collaborated with other customer...
# 455  how do you motivate your team to provide excel...
#
# [459 rows x 9 columns]

# %%
cleaned_df.to_csv("Final_Customer_Representative_Data.csv", index=False)
